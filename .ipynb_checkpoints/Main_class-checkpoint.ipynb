# %%
import function as f
import sys

def teacher_menu():
    print("\n\n")
    print('its teacher menu')
    while True:
        print('1.Display Book List\n2.Issue book\n3.Return book\n4.To exit')
        c=int(input())
        if c=='1':
            f.displayBooks()
        elif c=='2':
            f.bookIssue()
        elif c=='3':
            f.bookReturn()
        elif c=='4':
            break
            
def admin_menu():
    print("\n\n")
    while True:
        print("1.>  Insert Book")
        print("2.>  Display Book List")
        print("3.>  Book Search")
        print("4.>  Book Issue")
        print("5.>  Book Return")
        print("6.>  Delete Book Record")
        print("7.>  Insert New Student")
        print("8.>  Display Student List")
        print("9.>  Student Search")
        print("10.> Delete Student Record")
        print("11.> Insert New Faculty")
        print("12.> Display Faculty")
        print("13.> Faculty Search")
        print("14.> Delete Faculty")
        print("0> Exit\n")
        n = int(input("Enter Your Choice: "))
        if n==1:
            f.bookStore()
        elif n==2:
            f.displayBooks()
        elif n==3:
            f.bookSearch()
        elif n==4:
            f.bookIssue()
        elif n==5:
            f.bookReturn()
        elif n==6:
            f.bookDelete()
        elif n==7:
            f.inputStudent()
        elif n==8:
            f.displayStudent()
        elif n==9:
            f.studentSearch()
        elif n==10:
            f.studentDelete()
        elif n==11:
            f.inputFaculty()
        elif n==12:
            f.displayFaculty()
        elif n==13:
            f.facultySearch()
        elif n==14:
            f.facultyDelete()    
        elif n==0:
            break
            
            
            
def student_menu():
    while(True):
        print("\n\n")
        print('1.Display Book List\n2.Issue book\n3.Return book\n4.To exit')
        c=int(input())
        if c=='1':
            f.displayBooks()
        elif c=='2':
            f.bookIssue()
        elif c=='3':
            f.bookReturn()
        elif c=='4':
            break


class main:
        def __init__(self):
            while(True):
                print("\n\n\n")
                print("****Welcome To Library Managmenet System****")
                print("1 for Admin")
                print("2 for Facalty")
                print("3 for Student")
                print("4 for exit")
                c=input("Enter Your Choise : ")
    
                if c=='1':
                    admin_menu()
        
                if c=='2':
                    teacher_menu()
        
                if c=='3':
                    student_menu()
        
                if c=='4':
                    print("Thank You For Using LMS ")
                    break
        
c=main()
# Out:
# ****Welcome To Library Managmenet System****
# 1 for Admin
# 2 for Facalty
# 3 for Student
# 4 for exit
# Enter Your Choise : 3
#
#
#
# 1.Display Book List
# 2.Issue book
# 3.Return book
# 4.To exit
# 4
#
#
#
# 1.Display Book List
# 2.Issue book
# 3.Return book
# 4.To exit
# 4
#
#
#
# 1.Display Book List
# 2.Issue book
# 3.Return book
# 4.To exit
# 4
#
#
#
# 1.Display Book List
# 2.Issue book
# 3.Return book
# 4.To exit
# 4
#
#
#
# 1.Display Book List
# 2.Issue book
# 3.Return book
# 4.To exit
# 4
#
#
#
# 1.Display Book List
# 2.Issue book
# 3.Return book
# 4.To exit
# 4
#
#
#
# 1.Display Book List
# 2.Issue book
# 3.Return book
# 4.To exit
# 1
#
#
#
# 1.Display Book List
# 2.Issue book
# 3.Return book
# 4.To exit
